# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import requests
import re

# %%
pagina = requests.get('https://www.marketwatch.com/investing/future/sb.1')
pagina.text
# Out:
# '\n\n\n<!DOCTYPE html>\n<html class="" lang="en">\n<head>\n        <title>SB.1 | Sugar #11 (IFUS $/lbs) Front Month Overview | MarketWatch</title>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, width=device-width">\n            <meta name="robots" content="noarchive, noodp">\n\n\n<link rel="dns-prefetch" href="//sts.wsj.net" />\n<link rel="dns-prefetch" href="//s.marketwatch.com" />\n<link rel="dns-prefetch" href="//video-api.wsj.com" />\n<link rel="dns-prefetch" href="//fonts.wsj.net" />\n<link rel="dns-prefetch" href="//m.wsj.net" />\n<link rel="dns-prefetch" href="//mwstream.wsj.net" />\n<link rel="dns-prefetch" href="//tags.tiqcdn.com" />\n<link rel="dns-prefetch" href="//s.ntv.io" />\n<link rel="dns-prefetch" href="//cdn.cxense.com" />\n<link rel="dns-prefetch" href="//a248.e.akamai.net" />\n<link rel="dns-prefetch" href="//om.dowjoneson
# ...

# %%
patron = r'<table class="table table--primary align--right">(.+?)'
#review = re.search(patron, pagina.text).group(2)
tabla = """<table class="table table--primary align--right">
                <thead class="table__head">
                    <tr class="table__row">
                        <th class="table__heading"></th>
                        <th class="table__heading">Last</th>
                        <th class="table__heading">Chg</th>
                        <th class="table__heading">Open</th>
                        <th class="table__heading">High</th>
                        <th class="table__heading">Low</th>
                        <th class="table__heading">Date/Time</th>
                    </tr>
                </thead>
                <tbody class="table__body">
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sb.1">Sugar #11 (IFUS $/lbs) Front Month</a></td>
                                <td class="table__cell ignore-color">27.43¢</td>
                                <td class="table__cell negative">-0.06</td>
                                <td class="table__cell">27.56¢</td>
                                <td class="table__cell">27.67¢</td>
                                <td class="table__cell">27.17¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:15 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbh24">Sugar No. 11 World Mar 2024</a></td>
                                <td class="table__cell ignore-color">27.43¢</td>
                                <td class="table__cell negative">-0.06</td>
                                <td class="table__cell">27.56¢</td>
                                <td class="table__cell">27.67¢</td>
                                <td class="table__cell">27.17¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:15 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbk24">Sugar No. 11 World May 2024</a></td>
                                <td class="table__cell ignore-color">26.13¢</td>
                                <td class="table__cell negative">-0.06</td>
                                <td class="table__cell">26.24¢</td>
                                <td class="table__cell">26.37¢</td>
                                <td class="table__cell">25.91¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:15 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbn24">Sugar No. 11 World Jul 2024</a></td>
                                <td class="table__cell ignore-color">25.07¢</td>
                                <td class="table__cell negative">-0.06</td>
                                <td class="table__cell">25.15¢</td>
                                <td class="table__cell">25.30¢</td>
                                <td class="table__cell">24.89¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:14 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbv24">Sugar No. 11 World Oct 2024</a></td>
                                <td class="table__cell ignore-color">24.49¢</td>
                                <td class="table__cell negative">-0.03</td>
                                <td class="table__cell">24.57¢</td>
                                <td class="table__cell">24.70¢</td>
                                <td class="table__cell">24.33¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:14 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbh25">Sugar No. 11 World Mar 2025</a></td>
                                <td class="table__cell ignore-color">24.35¢</td>
                                <td class="table__cell negative">-0.02</td>
                                <td class="table__cell">24.42¢</td>
                                <td class="table__cell">24.55¢</td>
                                <td class="table__cell">24.22¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:07 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbk25">Sugar No. 11 World May 2025</a></td>
                                <td class="table__cell ignore-color">22.95¢</td>
                                <td class="table__cell positive">0.04</td>
                                <td class="table__cell">22.95¢</td>
                                <td class="table__cell">23.11¢</td>
                                <td class="table__cell">22.84¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:07 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbn25">Sugar No. 11 World Jul 2025</a></td>
                                <td class="table__cell ignore-color">21.80¢</td>
                                <td class="table__cell positive">0.10</td>
                                <td class="table__cell">21.73¢</td>
                                <td class="table__cell">21.91¢</td>
                                <td class="table__cell">21.66¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:06 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbv25">Sugar No. 11 World Oct 2025</a></td>
                                <td class="table__cell ignore-color">21.25¢</td>
                                <td class="table__cell positive">0.13</td>
                                <td class="table__cell">21.18¢</td>
                                <td class="table__cell">21.34¢</td>
                                <td class="table__cell">21.10¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:05 p.m.</td>
                            </tr>
                            <tr class="table__row">
                                <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sbh26">Sugar No. 11 World Mar 2026</a></td>
                                <td class="table__cell ignore-color">21.21¢</td>
                                <td class="table__cell positive">0.16</td>
                                <td class="table__cell">21.18¢</td>
                                <td class="table__cell">21.22¢</td>
                                <td class="table__cell">21.08¢</td>
                                <td class="table__cell u-secondary">Oct 18, 2023 12:05 p.m.</td>
                            </tr>
                </tbody>
            </table>"""

# %%
texto_limpio = re.sub(r'[\t\n\r\f\v]+', ' ', pagina.text)
texto_limpio
# Out:
# ' <!DOCTYPE html> <html class="" lang="en"> <head>         <title>SB.1 | Sugar #11 (IFUS $/lbs) Front Month Overview | MarketWatch</title>         <meta charset="utf-8">         <meta http-equiv="X-UA-Compatible" content="IE=edge">         <meta name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, width=device-width">             <meta name="robots" content="noarchive, noodp"> <link rel="dns-prefetch" href="//sts.wsj.net" /> <link rel="dns-prefetch" href="//s.marketwatch.com" /> <link rel="dns-prefetch" href="//video-api.wsj.com" /> <link rel="dns-prefetch" href="//fonts.wsj.net" /> <link rel="dns-prefetch" href="//m.wsj.net" /> <link rel="dns-prefetch" href="//mwstream.wsj.net" /> <link rel="dns-prefetch" href="//tags.tiqcdn.com" /> <link rel="dns-prefetch" href="//s.ntv.io" /> <link rel="dns-prefetch" href="//cdn.cxense.com" /> <link rel="dns-prefetch" href="//a248.e.akamai.net" /> <link rel="dns-prefetch" href="//om.dowjoneson.com" /> <link rel="dns-pre
# ...

# %%
patron = r'<span class="label">Recent Contracts</span>(.+?)</table>'
review = re.search(patron, texto_limpio).group(0)
review
# Out:
# '<span class="label">Recent Contracts</span>                 </h2>             </header>             <table class="table table--primary align--right">                 <thead class="table__head">                     <tr class="table__row">                         <th class="table__heading"></th>                         <th class="table__heading">Last</th>                         <th class="table__heading">Chg</th>                         <th class="table__heading">Open</th>                         <th class="table__heading">High</th>                         <th class="table__heading">Low</th>                         <th class="table__heading">Date/Time</th>                     </tr>                 </thead>                 <tbody class="table__body">                             <tr class="table__row">                                 <td class="table__cell"><a class="link" href="https://www.marketwatch.com/investing/future/sb.1">Sugar #11 (IFUS $/lbs) Front Month</a></td>              
# ...

# %%
patron = r'([0-9][0-9]\.[0-9][0-9])'
coincidencias = re.findall(patron, review)

# Imprime todas las coincidencias
for coincidencia in coincidencias:
       print(coincidencia)
# Out:
# 27.43
# 27.56
# 27.67
# 27.17
# 27.43
# 27.56
# 27.67
# 27.17
# 26.13
# 26.24
# 26.37
# 25.91
# 25.08
# 25.15
# 25.30
# 24.89
# 24.49
# 24.57
# 24.70
# 24.33
# 24.35
# 24.42
# 24.55
# 24.22
# 22.95
# 22.95
# 23.11
# 22.84
# 21.80
# 21.73
# 21.91
# 21.66
# 21.25
# 21.18
# 21.34
# 21.10
# 21.21
# 21.18
# 21.22
# 21.08

# %%
dataset = pd.read_csv("BankChurners.csv")
dataset.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
dataset.Customer_Age.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns

sns.barplot(dataset, x="Gender", y="Customer_Age")
plt.title("Titulo")
plt.show()
